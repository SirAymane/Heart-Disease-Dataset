# %% [markdown]
# ### 1. Relación entre nivel de colesterol y presión arterial en reposo.
#
# ##### Ambos parámetros son conocidos por ser factores útiles en la determinación de riesgo cardiovascular. Responderemos a la pregunta de si estos dos factores tienen relación entre sí o si son independientes. La hipótesis es que sí tienen relación, ya que el tema está ampliamente estudiado. Sin embargo, comprobaremos en la presente muestra si esto se cumple.
# ##### En la siguiente gráfica podemos observar que en valores de presión arterial en reposo alta (>100) se concentran también los valores de colesterol considerados altos (>200). Esto confirma una relación de proporcionalidad directa entre ambos parámetros: a mayor nivel de colesterol, mayor presión arterial en reposo.

# %%
from scripts.mel.ex1 import get_relation_chol_trestbps

get_relation_chol_trestbps("heart_clean.csv")

# %% [markdown]
# ### 2. Presencia de patología cardiovascular en función del sexo y la frecuencia cardíaca máxima alcanzada
#
# ##### Observaremos si existe relación entre frecuencia cardíaca máxima alcanzada y enfermedad, y si el sexo determina alguna diferencia en ésta.
# ##### En la siguiente gráfica podemos observar que el mayor número de individuos enfermos se concentra, tanto en hombres como en mujeres, en valores de frecuencia cardíaca máxima alcanzada en la parte derecha de la gráfica. Es decir, que a mayores elevaciones de la frecuencia cardíaca podemos inferir mayor riesgo de patología cardiovascular.
# ##### No obstante, se pueden observar matices en este patrón en función del sexo. En el caso de las mujeres habría una presencia de patología en valores de frecuencia cardíaca máxima más bajas (~160 ppm). Esto podría explicarse por motivos fisiólogicos y físicos como un menor tamaño promedio del corazón. Además, por debajo de este umbral también observamos más personas enfermas en proporción a las sanas, por lo que parece que la frecuencia cardíaca sería un factor más determinante en hombres que en mujeres y estas últimas sufrirían patologías cardiovasculares menos relacionadas con ese parámetro.

# %%
from scripts.mel.ex2 import get_condicion_by_hr_sex

get_condicion_by_hr_sex("heart_labels.csv")

# %% [markdown]
# ### 3. Relación entre nivel de descenso del segmento ST inducido por el ejercicio y presencia de angina en individuos sanos y enfermos.
#
# ##### Observaremos si existe relación entre los dos parámetros y si existen diferencias en función del estado de salud de los individuos de la muestra.
#
# ##### Según los resultados mostrados en la gráfica, observamos que existe cierta relación entre un mayor nivel de descenso del segmento ST inducido por el ejercicio y la presencia de angina inducida por el ejercicio tanto en personas sanas como con patología diagnosticada, siendo más acusada en las segundas.

# %%
from scripts.mel.ex3 import get_condition_exang_oldpeak

get_condition_exang_oldpeak("heart_labels.csv")
